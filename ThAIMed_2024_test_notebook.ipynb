# %% [markdown]
# ## Import libraries
#
# Import the libraries that are used throughout the rest of the notebook

# %%
# @title Import libraries
# %matplotlib inline

import ipywidgets as widgets
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from IPython.display import display

# %% [markdown]
# ## Load data
#
# Load the data that will be used in the rest of the notebook

# %%
# @title Load data


demographics_columns = [
    "RIAGENDR", "RIDAGEYR", "RIDAGEMN", "RIDRETH1", "RIDRETH3", "DMDEDUC3", "DMDEDUC2", "INDHHIN2", "INDFMIN2"
]
examination_columns = [
    "BPXCHR", "BPXPLS", "BPXSY1", "BPXDI1", "BPXSY2", "BPXDI2", "BPXSY3", "BPXDI3", "BPXSY4", "BPXDI4", "BMXWT", "BMXHT", "BMXBMI", "BMXWAIST", "BMXHIP",
]
lab_columns = [
     "LBDHDD", "LBXTC", "LBXGLU",
]
questionnaire_columns = [
    "DIQ010", "DIQ160", "DIQ170", "DIQ172", "DIQ175A"
]

demographics_df = pd.read_csv('https://raw.githubusercontent.com/RileyZurrin/NHANES_Extractor/main/Data_scraper/NHANES_2017-2018/demographics.csv').set_index('SEQN')
dietary_df = pd.read_csv('https://raw.githubusercontent.com/RileyZurrin/NHANES_Extractor/main/Data_scraper/NHANES_2017-2018/dietary.csv').set_index('SEQN')
examination_df = pd.read_csv('https://raw.githubusercontent.com/RileyZurrin/NHANES_Extractor/main/Data_scraper/NHANES_2017-2018/examination.csv').set_index('SEQN')
labs_df = pd.read_csv('https://raw.githubusercontent.com/RileyZurrin/NHANES_Extractor/main/Data_scraper/NHANES_2017-2018/laboratory.csv').set_index('SEQN')
questionnaire_df = pd.read_csv('https://raw.githubusercontent.com/RileyZurrin/NHANES_Extractor/main/Data_scraper/NHANES_2017-2018/questionnaire.csv').set_index('SEQN')

encodings_df = pd.read_csv('https://raw.githubusercontent.com/RileyZurrin/NHANES_Extractor/main/Dictionary_scraper/NHANES_2017-2018/encodings.csv')
description_df = pd.read_csv('https://raw.githubusercontent.com/RileyZurrin/NHANES_Extractor/main/Dictionary_scraper/NHANES_2017-2018/descriptions.csv')
master_df = demographics_df[demographics_columns]
master_df = master_df.join(other=[examination_df[examination_columns], labs_df[lab_columns], questionnaire_df[questionnaire_columns]], how="outer")

final_columns = demographics_columns + examination_columns + lab_columns + questionnaire_columns
master_encodings = encodings_df[encodings_df["Variable"].isin(final_columns)]
master_descriptions = description_df[description_df["Variable"].isin(final_columns)]
master_meta_df = master_descriptions.merge(right=master_encodings, on="Variable", how="outer")

master_meta_df
# Out:
#     Variable       DataType                                     Label  \
# 0   RIAGENDR   demographics                                    Gender
# 1   RIDAGEYR   demographics                 Age in years at screening
# 2   RIDAGEMN   demographics  Age in months at screening - 0 to 24 mos
# 3   RIDRETH1   demographics                      Race/Hispanic origin
# 4   RIDRETH3   demographics          Race/Hispanic origin w/ NH Asian
# 5   DMDEDUC3   demographics     Education level - Children/Youth 6-19
# 6   DMDEDUC2   demographics              Education level - Adults 20+
# 7   INDHHIN2   demographics                   Annual household income
# 8   INDFMIN2   demographics                      Annual family income
# 9     BPXCHR    examination                 60 sec HR (30 sec HR * 2)
# 10    BPXPLS    examination         60 sec. pulse (30 sec. pulse * 2)
# 11    BPXSY1    examination      Systolic: Blood pres (1st rdg) mm Hg
# 12    BPXDI1    examination     Diastolic: Blood pres (1st rdg) mm Hg
# 13    BPXSY2    examination      Systolic: Blood pres (2nd rdg) mm Hg
# 14    BPXDI2    examination     Diastolic: Blood pres (2nd rdg) mm Hg
# 15    BPXSY3    examination      Systolic: Blood pres (3rd rdg) mm Hg
# 16    BPXDI3    examination     Diastolic: Blood pres (3rd rdg) mm Hg
# 17    BPXSY4    examination      Systolic: Blood pres (4th rdg) mm Hg
# 18    BPXDI4    examination     Diastolic: Blood pres (4th rdg) mm Hg
# 19     BMXWT    examination                               Weight (kg)
# 20     BMXHT    examination                      Standing Height (cm)
# 21    BMXBMI    examination                 Body Mass Index (kg/m**2)
# 22  BMXWAIST    examination                  Waist Circumference (cm)
# 23    BMXHIP    examination                    Hip Circumference (cm)
# 24    LBDHDD     laboratory            Direct HDL-Cholesterol (mg/dL)
# 25     LBXTC     laboratory                 Total Cholesterol (mg/dL)
# 26    LBXGLU     laboratory                   Fasting Glucose (mg/dL)
# 27    DIQ010  questionnaire             Doctor told you have diabetes
# 28    DIQ160  questionnaire            Ever told you have prediabetes
# 29    DIQ170  questionnaire   Ever told have health risk for diabetes
# 30    DIQ172  questionnaire        Feel could be at risk for diabetes
# 31   DIQ175A  questionnaire                            Family history
#
#                                     Plain Description  \
# 0                          Gender of the participant.
# 1   Age in years of the participant at the time of...
# 2   Age in months of the participant at the time o...
# 3   Recode of reported race and Hispanic origin in...
# 4   Recode of reported race and Hispanic origin in...
# 5   What is the highest grade or level of school {...
# 6   What is the highest grade or level of school {...
# 7   Total household income (reported as a range va...
# 8   Total family income (reported as a range value...
# 9                           60 sec HR (30 sec HR * 2)
# 10                  60 sec. pulse (30 sec. pulse * 2)
# 11    Systolic:  Blood pressure (first reading) mm Hg
# 12   Diastolic:  Blood pressure (first reading) mm Hg
# 13   Systolic:  Blood pressure (second reading) mm Hg
# 14   Diastolic: Blood pressure (second reading) mm Hg
# 15    Systolic:  Blood pressure (third reading) mm Hg
# 16    Diastolic: Blood pressure (third reading) mm Hg
# 17  Systolic:  Blood pressure (fourth reading if n...
# 18  Diastolic: Blood pressure (fourth reading if n...
# 19                                        Weight (kg)
# 20                               Standing Height (cm)
# 21                          Body Mass Index (kg/m**2)
# 22                           Waist Circumference (cm)
# 23                             Hip Circumference (cm)
# 24                     Direct HDL-Cholesterol (mg/dL)
# 25                          Total Cholesterol (mg/dL)
# 26                            Fasting Glucose (mg/dL)
# 27  The next questions are about specific medical ...
# 28  {Have you/Has SP} ever been told by a doctor o...
# 29  {Have you/Has SP} ever been told by a doctor o...
# 30  {Do you/Does SP} feel {you/he/she} could be at...
# 31  Why {Do you/Does SP} think {you are/he is/she ...
#
#                                         Target  \
# 0    Both males and females 0 YEARS -150 YEARS
# 1    Both males and females 0 YEARS -150 YEARS
# 2      Both males and females 0 YEARS -2 YEARS
# 3    Both males and females 0 YEARS -150 YEARS
# 4    Both males and females 0 YEARS -150 YEARS
# 5     Both males and females 6 YEARS -19 YEARS
# 6   Both males and females 20 YEARS -150 YEARS
# 7    Both males and females 0 YEARS -150 YEARS
# 8    Both males and females 0 YEARS -150 YEARS
# 9      Both males and females 0 YEARS -7 YEARS
# 10   Both males and females 8 YEARS -150 YEARS
# 11   Both males and females 8 YEARS -150 YEARS
# 12   Both males and females 8 YEARS -150 YEARS
# 13   Both males and females 8 YEARS -150 YEARS
# 14   Both males and females 8 YEARS -150 YEARS
# 15   Both males and females 8 YEARS -150 YEARS
# 16   Both males and females 8 YEARS -150 YEARS
# 17   Both males and females 8 YEARS -150 YEARS
# 18   Both males and females 8 YEARS -150 YEARS
# 19   Both males and females 0 YEARS -150 YEARS
# 20   Both males and females 2 YEARS -150 YEARS
# 21   Both males and females 2 YEARS -150 YEARS
# 22   Both males and females 2 YEARS -150 YEARS
# 23  Both males and females 12 YEARS -150 YEARS
# 24   Both males and females 6 YEARS -150 YEARS
# 25   Both males and females 6 YEARS -150 YEARS
# 26  Both males and females 12 YEARS -150 YEARS
# 27   Both males and females 1 YEARS -150 YEARS
# 28  Both males and females 12 YEARS -150 YEARS
# 29  Both males and females 12 YEARS -150 YEARS
# 30  Both males and females 12 YEARS -150 YEARS
# 31  Both males and females 12 YEARS -150 YEARS
#
#                                              Encoding
# 0            {1: 'Male', 2: 'Female', '.': 'Missing'}
# 1    {80: '80 years of age and over', '.': 'Missing'}
# 2                                    {'.': 'Missing'}
# 3   {1: 'Mexican American', 2: 'Other Hispanic', 3...
# 4   {1: 'Mexican American', 2: 'Other Hispanic', 3...
# 5   {0: 'Never attended / kindergarten only', 1: '...
# 6   {1: 'Less than 9th grade', 2: '9-11th grade (I...
# 7   {1: '$ 0 to $ 4,999', 2: '$ 5,000 to $ 9,999',...
# 8   {1: '$ 0 to $ 4,999', 2: '$ 5,000 to $ 9,999',...
# 9                                    {'.': 'Missing'}
# 10                                   {'.': 'Missing'}
# 11                                   {'.': 'Missing'}
# 12                                   {'.': 'Missing'}
# 13                                   {'.': 'Missing'}
# 14                                   {'.': 'Missing'}
# 15                                   {'.': 'Missing'}
# 16                                   {'.': 'Missing'}
# 17                                   {'.': 'Missing'}
# 18                                   {'.': 'Missing'}
# 19                                   {'.': 'Missing'}
# 20                                   {'.': 'Missing'}
# 21                                   {'.': 'Missing'}
# 22                                   {'.': 'Missing'}
# 23                                   {'.': 'Missing'}
# 24                                   {'.': 'Missing'}
# 25                                   {'.': 'Missing'}
# 26                                   {'.': 'Missing'}
# 27  {1: 'Yes', 2: 'No', 3: 'Borderline', 7: 'Refus...
# 28  {1: 'Yes', 2: 'No', 7: 'Refused', 9: "Don't kn...
# 29  {1: 'Yes', 2: 'No', 7: 'Refused', 9: "Don't kn...
# 30  {1: 'Yes', 2: 'No', 7: 'Refused', 9: "Don't kn...
# 31  {10: 'Family history', 77: 'Refused', 99: "Don...

# %% [markdown]
# ## Exploring the dataset
#
# Use the below cells to get a feeling for the dataset.
#
# You can plot a histogram (normalised or unnormalised) of the selected field

# %%
# @title Visualising data code

def plot_histogram(field_desc, split_on_desc, normalise, split):
    field = master_meta_df[master_meta_df['Label'] == field_desc]['Variable'].values[0]
    if split:
      split_on = master_meta_df[master_meta_df['Label'] == split_on_desc]['Variable'].values[0]
    else:
      split_on = None

    if normalise:
        sns.histplot(master_df, x=field, hue=split_on, stat='probability', common_norm=False, kde=True)
    else:
        sns.histplot(master_df, x=field, hue=split_on, kde=True)

    plt.show()

hist_widgets = widgets.interact(
    plot_histogram,
    field_desc=widgets.Dropdown(options=master_meta_df['Label'], value=master_meta_df['Label'][20], description='Field to plot:', disabled=False),
    split_on_desc=widgets.Dropdown(options=master_meta_df['Label'], value=master_meta_df['Label'][0], description='Split by:', disabled=False),
    normalise=widgets.Checkbox(value=False),
    split=widgets.Checkbox(value=True)
)
# Out:
# interactive(children=(Dropdown(description='Field to plot:', index=20, options=('Gender', 'Age in years at scr…
